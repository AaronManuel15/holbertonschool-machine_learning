# %%
import tensorflow.keras as K
# Out:
# 2023-03-21 21:28:24.021941: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-21 21:28:24.473655: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-21 21:28:24.529099: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-21 21:28:24.529120: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-21 21:28:26.045005: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-21 21:28:26.045168: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-21 21:28:26.045179: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
"""Task 0: Inception Block"""

def inception_block(A_prev, filters):
    """builds an inception block as described in Going Deeper with
        Convolutions (2014)
    Args:
        A_prev: output from the previous layer
        filters: tuple or list containing F1, F3R, F3,F5R, F5, FPP, respectively:
            F1: number of filters in the 1x1 convolution
            F3R: number of filters in the 1x1 convolution before the 3x3 convolution
            F3: number of filters in the 3x3 convolution
            F5R: number of filters in the 1x1 convolution before the 5x5 convolution
            F5: number of filters in the 5x5 convolution
            FPP: number of filters in the 1x1 convolution after the max pooling
    Returns:
        concatenated output of the inception block"""
    
    f1, f3r, f3, f5r, f5, fpp = filters

    conv1 = K.layers.Conv2D(filters=f1, kernel_size=(1, 1), padding='same',
                            activation='relu')(A_prev)
    conv2a = K.layers.Conv2D(filters=f3r, kernel_size=(1, 1), padding='same',
                            activation='relu')(A_prev)
    conv2b = K.layers.Conv2D(filters=f3, kernel_size=(3, 3), padding='same',
                            activation='relu')(conv2a)
    conv3a = K.layers.Conv2D(filters=f5r, kernel_size=(1, 1), padding='same',
                             activation='relu')(A_prev)
    conv3b = K.layers.Conv2D(filters=f5, kernel_size=(5, 5), padding='same',
                             activation='relu')(conv3a)
    pool1 = K.layers.MaxPooling2D(pool_size=(3, 3), strides=(1, 1),
                                  padding='same')(A_prev)
    conv4 = K.layers.Conv2D(filters=fpp, kernel_size=(1, 1), padding='same',
                            activation='relu')(pool1)
    output = K.layers.Concatenate()([conv1, conv2b, conv3b, conv4])
    return output

# %%
if __name__ == '__main__':
    X = K.Input(shape=(224, 224, 3))
    Y = inception_block(X, [64, 96, 128, 16, 32, 32])
    model = K.models.Model(inputs=X, outputs=Y)
    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 224, 224, 96  384         ['input_4[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 224, 224, 16  64          ['input_4[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 224, 224, 3)  0          ['input_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 224, 224, 64  256         ['input_4[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 224, 224, 12  110720      ['conv2d_19[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 224, 224, 32  12832       ['conv2d_21[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 224, 224, 32  128         ['max_pooling2d_3[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 25  0           ['conv2d_18[0][0]',
#                                 6)                                'conv2d_20[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]']
#
# ==================================================================================================
# Total params: 124,384
# Trainable params: 124,384
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
"""Task 1: Inception Network"""


def inception_network():
    """builds the inception network as described in Going Deeper with
        Convolutions (2014)
    Returns:
        Keras model"""

    init = K.initializers.he_normal()
    inputs = K.Input(shape=(224, 224, 3))
    conv1 = K.layers.Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2),
                            padding='same', activation='relu',
                            kernel_initializer=init)(inputs)
    poo1 = K.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2),
                                 padding='same')(conv1)
    conv2a = K.layers.Conv2D(filters=64, kernel_size=(1, 1), padding='same',
                            activation='relu',
                            kernel_initializer=init)(poo1)
    conv2b = K.layers.Conv2D(filters=192, kernel_size=(3, 3), padding='same',
                            activation='relu',
                            kernel_initializer=init)(conv2a)
    pool2 = K.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2),
                                  padding='same')(conv2b)
    block1 = inception_block(pool2, [64, 96, 128, 16, 32, 32])
    block2 = inception_block(block1, [128, 128, 192, 32, 96, 64])
    pool3 = K.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2),
                                  padding='same')(block2)
    block3 = inception_block(pool3, [192, 96, 208, 16, 48, 64])
    block4 = inception_block(block3, [160, 112, 224, 24, 64, 64])
    block5 = inception_block(block4, [128, 128, 256, 24, 64, 64])
    block6 = inception_block(block5, [112, 144, 288, 32, 64, 64])
    block7 = inception_block(block6, [256, 160, 320, 32, 128, 128])
    pool4 = K.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2),
                                  padding='same')(block7)
    block8 = inception_block(pool4, [256, 160, 320, 32, 128, 128])
    block9 = inception_block(block8, [384, 192, 384, 48, 128, 128])
    pool5 = K.layers.AveragePooling2D(pool_size=(7, 7), strides=(7, 7),
                                      padding='valid')(block9)
    dropout = K.layers.Dropout(rate=0.4)(pool5)
    dense = K.layers.Dense(units=1000, activation='softmax',
                           kernel_initializer=init)(dropout)
    model = K.Model(inputs=inputs, outputs=dense)
    return model

# %%
if __name__ == '__main__':
    model = inception_network()
    model.summary()
# Out:
# /home/ediddev/.local/lib/python3.8/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_27 (Conv2D)             (None, 112, 112, 64  9472        ['input_9[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 64)  0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 56, 56, 64)   4160        ['max_pooling2d_4[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 56, 56, 192)  110784      ['conv2d_28[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 192)  0          ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 28, 28, 96)   18528       ['max_pooling2d_5[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 28, 28, 16)   3088        ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d_5[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 28, 28, 64)   12352       ['max_pooling2d_5[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 28, 28, 128)  110720      ['conv2d_31[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 28, 28, 32)   12832       ['conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 28, 28, 32)   6176        ['max_pooling2d_6[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 256)  0           ['conv2d_30[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 28, 28, 32)   8224        ['concatenate_4[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 28, 28, 256)  0          ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate_4[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 28, 28, 192)  221376      ['conv2d_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 28, 28, 96)   76896       ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 28, 28, 64)   16448       ['max_pooling2d_7[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 28, 28, 480)  0           ['conv2d_36[0][0]',
#                                                                   'conv2d_38[0][0]',
#                                                                   'conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 480)  0          ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 96)   46176       ['max_pooling2d_8[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 16)   7696        ['max_pooling2d_8[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 480)  0          ['max_pooling2d_8[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 192)  92352       ['max_pooling2d_8[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 208)  179920      ['conv2d_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 48)   19248       ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 64)   30784       ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_42[0][0]',
#                                                                   'conv2d_44[0][0]',
#                                                                   'conv2d_46[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_6[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_6[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 160)  82080       ['concatenate_6[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 224)  226016      ['conv2d_49[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_10[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_48[0][0]',
#                                                                   'conv2d_50[0][0]',
#                                                                   'conv2d_52[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_7[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_7[0][0]']
#  )
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 256)  295168      ['conv2d_55[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_11[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_54[0][0]',
#                                                                   'conv2d_56[0][0]',
#                                                                   'conv2d_58[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 14, 14, 144)  73872       ['concatenate_8[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 14, 14, 32)   16416       ['concatenate_8[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_8[0][0]']
#  )
#
#  conv2d_60 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_8[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 14, 14, 288)  373536      ['conv2d_61[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 14, 14, 64)   51264       ['conv2d_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_12[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 14, 14, 528)  0           ['conv2d_60[0][0]',
#                                                                   'conv2d_62[0][0]',
#                                                                   'conv2d_64[0][0]',
#                                                                   'conv2d_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 14, 14, 160)  84640       ['concatenate_9[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 14, 14, 32)   16928       ['concatenate_9[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 14, 14, 528)  0          ['concatenate_9[0][0]']
#  )
#
#  conv2d_66 (Conv2D)             (None, 14, 14, 256)  135424      ['concatenate_9[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 14, 14, 320)  461120      ['conv2d_67[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 14, 14, 128)  102528      ['conv2d_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 14, 14, 128)  67712       ['max_pooling2d_13[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 14, 14, 832)  0           ['conv2d_66[0][0]',
#                                                                   'conv2d_68[0][0]',
#                                                                   'conv2d_70[0][0]',
#                                                                   'conv2d_71[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_10[0][0]']
#  )
#
#  conv2d_73 (Conv2D)             (None, 7, 7, 160)    133280      ['max_pooling2d_14[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 7, 7, 32)     26656       ['max_pooling2d_14[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 7, 7, 832)   0           ['max_pooling2d_14[0][0]']
#  )
#
#  conv2d_72 (Conv2D)             (None, 7, 7, 256)    213248      ['max_pooling2d_14[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 7, 7, 320)    461120      ['conv2d_73[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 7, 7, 128)    102528      ['conv2d_75[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_15[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 7, 7, 832)    0           ['conv2d_72[0][0]',
#                                                                   'conv2d_74[0][0]',
#                                                                   'conv2d_76[0][0]',
#                                                                   'conv2d_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 7, 7, 192)    159936      ['concatenate_11[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 7, 7, 48)     39984       ['concatenate_11[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_11[0][0]']
#  )
#
#  conv2d_78 (Conv2D)             (None, 7, 7, 384)    319872      ['concatenate_11[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 7, 7, 384)    663936      ['conv2d_79[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 7, 7, 128)    153728      ['conv2d_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_16[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 7, 7, 1024)   0           ['conv2d_78[0][0]',
#                                                                   'conv2d_80[0][0]',
#                                                                   'conv2d_82[0][0]',
#                                                                   'conv2d_83[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 1024)  0           ['concatenate_12[0][0]']
#  ing2D)
#
#  dropout (Dropout)              (None, 1, 1, 1024)   0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1, 1, 1000)   1025000     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 6,998,552
# Trainable params: 6,998,552
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
"""Task 2: Identity Block"""

def identity_block(A_prev, filters):
    """Builds an identity block as described in Deep Residual Learning for
        Image Recognition (2015)
    Args:
        A_prev: output from the previous layer
        filters: tuple or list containing F11, F3, F12, respectively:
            F11: number of filters in the first 1x1 convolution
            F3: number of filters in the 3x3 convolution
            F12: number of filters in the second 1x1 convolution
    Returns:
        activated output of the identity block"""

    F11, F3, F12 = filters
    init = K.initializers.he_normal()
    conv1 = K.layers.Conv2D(filters=F11, kernel_size=(1, 1), padding='same',
                            kernel_initializer=init)(A_prev)
    bn1 = K.layers.BatchNormalization(axis=3)(conv1)
    act1 = K.layers.Activation('relu')(bn1)
    conv2 = K.layers.Conv2D(filters=F3, kernel_size=(3, 3), padding='same',
                            kernel_initializer=init)(act1)
    bn2 = K.layers.BatchNormalization(axis=3)(conv2)
    act2 = K.layers.Activation('relu')(bn2)
    conv3 = K.layers.Conv2D(filters=F12, kernel_size=(1, 1), padding='same',
                            kernel_initializer=init)(act2)
    bn3 = K.layers.BatchNormalization(axis=3)(conv3)
    add = K.layers.Add()([bn3, A_prev])
    act3 = K.layers.Activation('relu')(add)
    return act3

# %%
if __name__ == '__main__':
    X = K.Input(shape=(224, 224, 256))
    Y = identity_block(X, [64, 64, 256])
    model = K.models.Model(inputs=X, outputs=Y)
    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 2  0           []
#                                 56)]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  16448       ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 224, 224, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 224, 224, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 25  16640       ['activation_1[0][0]']
#                                 6)
# 2023-03-21 21:28:35.236457: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-21 21:28:35.236549: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-21 21:28:35.236613: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (BOBO-CODE): /proc/driver/nvidia/version does not exist
# 2023-03-21 21:28:35.238136: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ediddev/.local/lib/python3.8/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
#  batch_normalization_2 (BatchNo  (None, 224, 224, 25  1024       ['conv2d_2[0][0]']
#  rmalization)                   6)
#
#  add (Add)                      (None, 224, 224, 25  0           ['batch_normalization_2[0][0]',
#                                 6)                                'input_1[0][0]']
#
#  activation_2 (Activation)      (None, 224, 224, 25  0           ['add[0][0]']
#                                 6)
#
# ==================================================================================================
# Total params: 71,552
# Trainable params: 70,784
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %%
"""Task 3: Projection Block"""

def projection_block(A_prev, filters, s=2):
    """Builds a projection block as described in Deep Residual Learning for
        Image Recognition (2015)
    Args:
        A_prev: output from the previous layer
        filters: tuple or list containing F11, F3, F12, respectively:
            F11: number of filters in the first 1x1 convolution
            F3: number of filters in the 3x3 convolution
            F12: number of filters in the second 1x1 convolution and the 1x1
                convolution in the shortcut connection
        s: stride of the first convolution in both the main path and the
            shortcut connection
    Returns:
        activated output of the projection block"""

    F11, F3, F12 = filters
    init = K.initializers.he_normal()
    conv1 = K.layers.Conv2D(filters=F11, kernel_size=(1, 1), strides=s,
                            padding='same', kernel_initializer=init)(A_prev)
    bn1 = K.layers.BatchNormalization(axis=3)(conv1)
    act1 = K.layers.Activation('relu')(bn1)
    conv2 = K.layers.Conv2D(filters=F3, kernel_size=(3, 3), padding='same',
                            kernel_initializer=init)(act1)
    bn2 = K.layers.BatchNormalization(axis=3)(conv2)
    act2 = K.layers.Activation('relu')(bn2)
    conv3 = K.layers.Conv2D(filters=F12, kernel_size=(1, 1), padding='same',
                            kernel_initializer=init)(act2)
    bn3 = K.layers.BatchNormalization(axis=3)(conv3)
    conv4 = K.layers.Conv2D(filters=F12, kernel_size=(1, 1), strides=s,
                            padding='same', kernel_initializer=init)(A_prev)
    bn4 = K.layers.BatchNormalization(axis=3)(conv4)
    add = K.layers.Add()([bn3, bn4])
    act3 = K.layers.Activation('relu')(add)
    return act3

# %%
if __name__ == '__main__':
    X = K.Input(shape=(224, 224, 3))
    Y = projection_block(X, [64, 64, 256])
    model = K.models.Model(inputs=X, outputs=Y)
    model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 64  256         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 64  36928       ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 64  256        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 25  16640       ['activation_4[0][0]']
#                                 6)
#
#  conv2d_6 (Conv2D)              (None, 112, 112, 25  1024        ['input_2[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  batch_normalization_6 (BatchNo  (None, 112, 112, 25  1024       ['conv2d_6[0][0]']
#  rmalization)                   6)
#
#  add_1 (Add)                    (None, 112, 112, 25  0           ['batch_normalization_5[0][0]',
#                                 6)                                'batch_normalization_6[0][0]']
#
#  activation_5 (Activation)      (None, 112, 112, 25  0           ['add_1[0][0]']
#                                 6)
#
# ==================================================================================================
# Total params: 57,408
# Trainable params: 56,128
# Non-trainable params: 1,280
# __________________________________________________________________________________________________
# /home/ediddev/.local/lib/python3.8/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
"""Task 4: ResNet-50"""

def resnet50():
    """Builds the ResNet-50 architecture as described in Deep Residual
        Learning for Image Recognition (2015)
    Returns:
        a Keras model"""

    init = K.initializers.he_normal()
    inputs = K.Input(shape=(224, 224, 3))
    conv1 = K.layers.Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2),
                            padding='same', kernel_initializer=init)(inputs)
    bn1 = K.layers.BatchNormalization(axis=3)(conv1)
    act1 = K.layers.Activation('relu')(bn1)
    pool1 = K.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2),
                                  padding='same')(act1)
    block1 = projection_block(pool1, [64, 64, 256], s=1)
    block2 = identity_block(block1, [64, 64, 256])
    block3 = identity_block(block2, [64, 64, 256])
    
    block4 = projection_block(block3, [128, 128, 512])
    block5 = identity_block(block4, [128, 128, 512])
    block6 = identity_block(block5, [128, 128, 512])
    block7 = identity_block(block6, [128, 128, 512])
    
    block8 = projection_block(block7, [256, 256, 1024])
    block9 = identity_block(block8, [256, 256, 1024])
    block10 = identity_block(block9, [256, 256, 1024])
    block11 = identity_block(block10, [256, 256, 1024])
    block12 = identity_block(block11, [256, 256, 1024])
    block13 = identity_block(block12, [256, 256, 1024])
    
    block14 = projection_block(block13, [512, 512, 2048])
    block15 = identity_block(block14, [512, 512, 2048])
    block16 = identity_block(block15, [512, 512, 2048])
    pool2 = K.layers.AveragePooling2D(pool_size=(7, 7), strides=(7, 7),
                                      padding='valid')(block16)
    dense = K.layers.Dense(units=1000, activation='softmax',
                           kernel_initializer=init)(pool2)
    return K.models.Model(inputs=inputs, outputs=dense)

# %%
if __name__ == '__main__':
    model = resnet50()
    model.summary()
# Out:
# /home/ediddev/.local/lib/python3.8/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_7 (Conv2D)              (None, 112, 112, 64  9472        ['input_3[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 112, 112, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 64)   36928       ['activation_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 256)  16640       ['activation_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 256)  16640       ['max_pooling2d[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_10[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_9 (Activation)      (None, 56, 56, 256)  0           ['add_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   16448       ['activation_9[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 256)  16640       ['activation_11[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_14[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_12 (Activation)     (None, 56, 56, 256)  0           ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 56, 56, 64)   16448       ['activation_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 56, 56, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_13[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 56, 56, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 56, 56, 256)  16640       ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 56, 56, 256)  0           ['batch_normalization_17[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 56, 56, 256)  0           ['add_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 128)  32896       ['activation_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_15[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_20[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 128)  512        ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_24[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_24[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_21[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_22[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 28, 28, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_23[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_27[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_27[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_24 (Activation)     (None, 28, 28, 512)  0           ['add_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_24[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_25[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 28, 28, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_26[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_30[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 28, 28, 512)  0           ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 256)  131328      ['activation_27[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_27[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_33[0][0]',
#                                 )                                 'batch_normalization_34[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_37[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_40[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_36[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_37[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_43[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_40[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_41[0][0]']
#                                 )
#
#  batch_normalization_46 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  add_13 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_46[0][0]',
#                                 )                                 'activation_39[0][0]']
#
#  activation_42 (Activation)     (None, 14, 14, 1024  0           ['add_13[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_42[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_43[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_44[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  add_14 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_49[0][0]',
#                                 )                                 'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 14, 14, 1024  0           ['add_14[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 512)    524800      ['activation_45[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_46[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_47[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_45[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_53[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_52[0][0]',
#                                                                   'batch_normalization_53[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_48[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_49[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_50[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_56[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_56[0][0]',
#                                                                   'activation_48[0][0]']
#
#  activation_51 (Activation)     (None, 7, 7, 2048)   0           ['add_16[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_51[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_52[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_53[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_59[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_59[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 7, 7, 2048)   0           ['add_17[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 2048)  0           ['activation_54[0][0]']
#  ing2D)
#
#  dropout (Dropout)              (None, 1, 1, 2048)   0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1, 1, 1000)   2049000     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
"""Task 5: Dense Block"""

def dense_block(X, nb_filters, growth_rate, layers):
    """Builds a dense block as described in Densely Connected Convolutional
        Networks
    Args:
        X: output from the previous layer
        nb_filters: integer representing the number of filters in X
        growth_rate: growth rate for the dense block
        layers: number of layers in the dense block
    Returns:
        The concatenated output of each layer within the Dense Block and the
            number of filters within the concatenated outputs, respectively"""

    init = K.initializers.he_normal()
    for _ in range(layers):
        bn1 = K.layers.BatchNormalization(axis=3)(X)
        act1 = K.layers.Activation('relu')(bn1)
        # bottleneck layer to reduce the number of input freature maps
        conv1 = K.layers.Conv2D(filters=4 * growth_rate, kernel_size=(1, 1),
                                padding='same', kernel_initializer=init)(act1)
        bn2 = K.layers.BatchNormalization(axis=3)(conv1)
        act2 = K.layers.Activation('relu')(bn2)
        # convolution layer
        conv2 = K.layers.Conv2D(filters=growth_rate, kernel_size=(3, 3),
                                padding='same', kernel_initializer=init)(act2)
        X = K.layers.concatenate([X, conv2])
        nb_filters += growth_rate
    
    return X, nb_filters

# %%
if __name__ == '__main__':
    X = K.Input(shape=(56, 56, 64))
    Y, nb_filters = dense_block(X, 64, 32, 6)
    model = K.models.Model(inputs=X, outputs=Y)
    model.summary()
    print(nb_filters)
# Out:
# /home/ediddev/.local/lib/python3.8/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 56, 56, 64)  0           []
#                                 ]
#
#  batch_normalization_72 (BatchN  (None, 56, 56, 64)  256         ['input_5[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_72[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 56, 56, 128)  8320        ['activation_67[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 56, 56, 128)  512        ['conv2d_72[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_73[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 56, 56, 32)   36896       ['activation_68[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 56, 56, 96)   0           ['input_5[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 56, 56, 96)  384         ['concatenate_6[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 56, 56, 96)   0           ['batch_normalization_74[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 56, 56, 128)  12416       ['activation_69[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 56, 56, 128)  512        ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_75[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 56, 56, 32)   36896       ['activation_70[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 56, 56, 128)  0           ['concatenate_6[0][0]',
#                                                                   'conv2d_75[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 56, 56, 128)  512        ['concatenate_7[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_76[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 56, 56, 128)  16512       ['activation_71[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 56, 56, 128)  512        ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_77[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 56, 56, 32)   36896       ['activation_72[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 56, 56, 160)  0           ['concatenate_7[0][0]',
#                                                                   'conv2d_77[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 56, 56, 160)  640        ['concatenate_8[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 56, 56, 160)  0           ['batch_normalization_78[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 56, 56, 128)  20608       ['activation_73[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 56, 56, 128)  512        ['conv2d_78[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_79[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 56, 56, 32)   36896       ['activation_74[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 56, 56, 192)  0           ['concatenate_8[0][0]',
#                                                                   'conv2d_79[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 56, 56, 192)  768        ['concatenate_9[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 56, 56, 192)  0           ['batch_normalization_80[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 56, 56, 128)  24704       ['activation_75[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 56, 56, 128)  512        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_81[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 56, 56, 32)   36896       ['activation_76[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 56, 56, 224)  0           ['concatenate_9[0][0]',
#                                                                   'conv2d_81[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 56, 56, 224)  896        ['concatenate_10[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 56, 56, 224)  0           ['batch_normalization_82[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 56, 56, 128)  28800       ['activation_77[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 56, 56, 128)  512        ['conv2d_82[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_83[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 56, 56, 32)   36896       ['activation_78[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 56, 56, 256)  0           ['concatenate_10[0][0]',
#                                                                   'conv2d_83[0][0]']
#
# ==================================================================================================
# Total params: 339,264
# Trainable params: 336,000
# Non-trainable params: 3,264
# __________________________________________________________________________________________________
# 256

# %%
"""Task 6: Transition Layer"""

def transition_layer(X, nb_filters, compression):
    """Builds a transition layer as described in Densely Connected
        Convolutional Networks
    Args:
        X: output from the previous layer
        nb_filters: integer representing the number of filters in X
        compression: compression factor for the transition layer
    Returns:
        The output of the transition layer and the number of filters within
            the output, respectively"""

    init = K.initializers.he_normal()
    bn1 = K.layers.BatchNormalization(axis=3)(X)
    act1 = K.layers.Activation('relu')(bn1)
    conv1 = K.layers.Conv2D(filters=int(nb_filters * compression),
                            kernel_size=(1, 1), padding='same',
                            kernel_initializer=init)(act1)
    avg_pool = K.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2),
                                         padding='valid')(conv1)
    return avg_pool, int(nb_filters * compression)

# %%
if __name__ == '__main__':
    X = K.Input(shape=(56, 56, 256))
    Y, nb_filters = transition_layer(X, 256, 0.5)
    model = K.models.Model(inputs=X, outputs=Y)
    model.summary()
    print(nb_filters)
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 56, 56, 256)]     0
#
#  batch_normalization_84 (Bat  (None, 56, 56, 256)      1024
#  chNormalization)
#
#  activation_79 (Activation)  (None, 56, 56, 256)       0
#
#  conv2d_84 (Conv2D)          (None, 56, 56, 128)       32896
#
#  average_pooling2d_1 (Averag  (None, 28, 28, 128)      0
#  ePooling2D)
#
# =================================================================
# Total params: 33,920
# Trainable params: 33,408
# Non-trainable params: 512
# _________________________________________________________________
# 128

# %%
"""Task 7: DenseNet-121"""

def densenet121(growth_rate=32, compression=1.0):
    """Builds the DenseNet-121 architecture as described in Densely Connected
        Convolutional Networks
    Args:
        growth_rate: growth rate
        compression: compression factor
    Returns:
        the keras model"""

    init = K.initializers.he_normal()
    inputs = K.Input(shape=(224, 224, 3))
    bn1 = K.layers.BatchNormalization(axis=3)(inputs)
    act1 = K.layers.Activation('relu')(bn1)
    conv1 = K.layers.Conv2D(filters=2 * growth_rate, kernel_size=(7, 7),
                            kernel_initializer=init, padding='same')(act1)
    pool1 = K.layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2),
                                  padding='same')(conv1)
    block1, nb_filters = dense_block(pool1, 2 * growth_rate, growth_rate, 6)
    transition_layer1, nb_filters = transition_layer(block1, nb_filters, compression)
    block2, nb_filters = dense_block(transition_layer1, nb_filters, growth_rate, 12)
    transition_layer2, nb_filters = transition_layer(block2, nb_filters, compression)
    block3, nb_filters = dense_block(transition_layer2, nb_filters, growth_rate, 24)
    transition_layer3, nb_filters = transition_layer(block3, nb_filters, compression)
    block4, nb_filters = dense_block(transition_layer3, nb_filters, growth_rate, 16)
    avg_pool = K.layers.AveragePooling2D(pool_size=(7, 7), padding='valid')(block4)
    dense = K.layers.Dense(units=1000, activation='softmax',
                           kernel_initializer=init)(avg_pool)
    model = K.models.Model(inputs=inputs, outputs=dense)
    return model

# %%
if __name__ == '__main__':
    model = densenet121(32, 0.5)
    model.summary()
# Out:
# /home/ediddev/.local/lib/python3.8/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  batch_normalization_112 (Batch  (None, 224, 224, 3)  12         ['input_9[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 224, 224, 3)  0           ['batch_normalization_112[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 224, 224, 64  9472        ['activation_107[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 112, 112, 64  0          ['conv2d_112[0][0]']
#                                 )
#
#  batch_normalization_113 (Batch  (None, 112, 112, 64  256        ['max_pooling2d_3[0][0]']
#  Normalization)                 )
#
#  activation_108 (Activation)    (None, 112, 112, 64  0           ['batch_normalization_113[0][0]']
#                                 )
#
#  conv2d_113 (Conv2D)            (None, 112, 112, 12  8320        ['activation_108[0][0]']
#                                 8)
#
#  batch_normalization_114 (Batch  (None, 112, 112, 12  512        ['conv2d_113[0][0]']
#  Normalization)                 8)
#
#  activation_109 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_114[0][0]']
#                                 8)
#
#  conv2d_114 (Conv2D)            (None, 112, 112, 32  36896       ['activation_109[0][0]']
#                                 )
#
#  concatenate_24 (Concatenate)   (None, 112, 112, 96  0           ['max_pooling2d_3[0][0]',
#                                 )                                 'conv2d_114[0][0]']
#
#  batch_normalization_115 (Batch  (None, 112, 112, 96  384        ['concatenate_24[0][0]']
#  Normalization)                 )
#
#  activation_110 (Activation)    (None, 112, 112, 96  0           ['batch_normalization_115[0][0]']
#                                 )
#
#  conv2d_115 (Conv2D)            (None, 112, 112, 12  12416       ['activation_110[0][0]']
#                                 8)
#
#  batch_normalization_116 (Batch  (None, 112, 112, 12  512        ['conv2d_115[0][0]']
#  Normalization)                 8)
#
#  activation_111 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_116[0][0]']
#                                 8)
#
#  conv2d_116 (Conv2D)            (None, 112, 112, 32  36896       ['activation_111[0][0]']
#                                 )
#
#  concatenate_25 (Concatenate)   (None, 112, 112, 12  0           ['concatenate_24[0][0]',
#                                 8)                                'conv2d_116[0][0]']
#
#  batch_normalization_117 (Batch  (None, 112, 112, 12  512        ['concatenate_25[0][0]']
#  Normalization)                 8)
#
#  activation_112 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_117[0][0]']
#                                 8)
#
#  conv2d_117 (Conv2D)            (None, 112, 112, 12  16512       ['activation_112[0][0]']
#                                 8)
#
#  batch_normalization_118 (Batch  (None, 112, 112, 12  512        ['conv2d_117[0][0]']
#  Normalization)                 8)
#
#  activation_113 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_118[0][0]']
#                                 8)
#
#  conv2d_118 (Conv2D)            (None, 112, 112, 32  36896       ['activation_113[0][0]']
#                                 )
#
#  concatenate_26 (Concatenate)   (None, 112, 112, 16  0           ['concatenate_25[0][0]',
#                                 0)                                'conv2d_118[0][0]']
#
#  batch_normalization_119 (Batch  (None, 112, 112, 16  640        ['concatenate_26[0][0]']
#  Normalization)                 0)
#
#  activation_114 (Activation)    (None, 112, 112, 16  0           ['batch_normalization_119[0][0]']
#                                 0)
#
#  conv2d_119 (Conv2D)            (None, 112, 112, 12  20608       ['activation_114[0][0]']
#                                 8)
#
#  batch_normalization_120 (Batch  (None, 112, 112, 12  512        ['conv2d_119[0][0]']
#  Normalization)                 8)
#
#  activation_115 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_120[0][0]']
#                                 8)
#
#  conv2d_120 (Conv2D)            (None, 112, 112, 32  36896       ['activation_115[0][0]']
#                                 )
#
#  concatenate_27 (Concatenate)   (None, 112, 112, 19  0           ['concatenate_26[0][0]',
#                                 2)                                'conv2d_120[0][0]']
#
#  batch_normalization_121 (Batch  (None, 112, 112, 19  768        ['concatenate_27[0][0]']
#  Normalization)                 2)
#
#  activation_116 (Activation)    (None, 112, 112, 19  0           ['batch_normalization_121[0][0]']
#                                 2)
#
#  conv2d_121 (Conv2D)            (None, 112, 112, 12  24704       ['activation_116[0][0]']
#                                 8)
#
#  batch_normalization_122 (Batch  (None, 112, 112, 12  512        ['conv2d_121[0][0]']
#  Normalization)                 8)
#
#  activation_117 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_122[0][0]']
#                                 8)
#
#  conv2d_122 (Conv2D)            (None, 112, 112, 32  36896       ['activation_117[0][0]']
#                                 )
#
#  concatenate_28 (Concatenate)   (None, 112, 112, 22  0           ['concatenate_27[0][0]',
#                                 4)                                'conv2d_122[0][0]']
#
#  batch_normalization_123 (Batch  (None, 112, 112, 22  896        ['concatenate_28[0][0]']
#  Normalization)                 4)
#
#  activation_118 (Activation)    (None, 112, 112, 22  0           ['batch_normalization_123[0][0]']
#                                 4)
#
#  conv2d_123 (Conv2D)            (None, 112, 112, 12  28800       ['activation_118[0][0]']
#                                 8)
#
#  batch_normalization_124 (Batch  (None, 112, 112, 12  512        ['conv2d_123[0][0]']
#  Normalization)                 8)
#
#  activation_119 (Activation)    (None, 112, 112, 12  0           ['batch_normalization_124[0][0]']
#                                 8)
#
#  conv2d_124 (Conv2D)            (None, 112, 112, 32  36896       ['activation_119[0][0]']
#                                 )
#
#  concatenate_29 (Concatenate)   (None, 112, 112, 25  0           ['concatenate_28[0][0]',
#                                 6)                                'conv2d_124[0][0]']
#
#  batch_normalization_125 (Batch  (None, 112, 112, 25  1024       ['concatenate_29[0][0]']
#  Normalization)                 6)
#
#  activation_120 (Activation)    (None, 112, 112, 25  0           ['batch_normalization_125[0][0]']
#                                 6)
#
#  conv2d_125 (Conv2D)            (None, 112, 112, 12  32896       ['activation_120[0][0]']
#                                 8)
#
#  average_pooling2d_3 (AveragePo  (None, 56, 56, 128)  0          ['conv2d_125[0][0]']
#  oling2D)
#
#  batch_normalization_126 (Batch  (None, 56, 56, 128)  512        ['average_pooling2d_3[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_126[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 56, 56, 128)  16512       ['activation_121[0][0]']
#
#  batch_normalization_127 (Batch  (None, 56, 56, 128)  512        ['conv2d_126[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_127[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_122[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 56, 56, 160)  0           ['average_pooling2d_3[0][0]',
#                                                                   'conv2d_127[0][0]']
#
#  batch_normalization_128 (Batch  (None, 56, 56, 160)  640        ['concatenate_30[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 56, 56, 160)  0           ['batch_normalization_128[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 56, 56, 128)  20608       ['activation_123[0][0]']
#
#  batch_normalization_129 (Batch  (None, 56, 56, 128)  512        ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_129[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_124[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 56, 56, 192)  0           ['concatenate_30[0][0]',
#                                                                   'conv2d_129[0][0]']
#
#  batch_normalization_130 (Batch  (None, 56, 56, 192)  768        ['concatenate_31[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 56, 56, 192)  0           ['batch_normalization_130[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 56, 56, 128)  24704       ['activation_125[0][0]']
#
#  batch_normalization_131 (Batch  (None, 56, 56, 128)  512        ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_131[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_126[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 56, 56, 224)  0           ['concatenate_31[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  batch_normalization_132 (Batch  (None, 56, 56, 224)  896        ['concatenate_32[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 56, 56, 224)  0           ['batch_normalization_132[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 56, 56, 128)  28800       ['activation_127[0][0]']
#
#  batch_normalization_133 (Batch  (None, 56, 56, 128)  512        ['conv2d_132[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_133[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_128[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 56, 56, 256)  0           ['concatenate_32[0][0]',
#                                                                   'conv2d_133[0][0]']
#
#  batch_normalization_134 (Batch  (None, 56, 56, 256)  1024       ['concatenate_33[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 56, 56, 256)  0           ['batch_normalization_134[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 56, 56, 128)  32896       ['activation_129[0][0]']
#
#  batch_normalization_135 (Batch  (None, 56, 56, 128)  512        ['conv2d_134[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_135[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_130[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 56, 56, 288)  0           ['concatenate_33[0][0]',
#                                                                   'conv2d_135[0][0]']
#
#  batch_normalization_136 (Batch  (None, 56, 56, 288)  1152       ['concatenate_34[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 56, 56, 288)  0           ['batch_normalization_136[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 56, 56, 128)  36992       ['activation_131[0][0]']
#
#  batch_normalization_137 (Batch  (None, 56, 56, 128)  512        ['conv2d_136[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_137[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_132[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 56, 56, 320)  0           ['concatenate_34[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  batch_normalization_138 (Batch  (None, 56, 56, 320)  1280       ['concatenate_35[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 56, 56, 320)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 56, 56, 128)  41088       ['activation_133[0][0]']
#
#  batch_normalization_139 (Batch  (None, 56, 56, 128)  512        ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_134[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 56, 56, 352)  0           ['concatenate_35[0][0]',
#                                                                   'conv2d_139[0][0]']
#
#  batch_normalization_140 (Batch  (None, 56, 56, 352)  1408       ['concatenate_36[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 56, 56, 352)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 56, 56, 128)  45184       ['activation_135[0][0]']
#
#  batch_normalization_141 (Batch  (None, 56, 56, 128)  512        ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_141[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_136[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 56, 56, 384)  0           ['concatenate_36[0][0]',
#                                                                   'conv2d_141[0][0]']
#
#  batch_normalization_142 (Batch  (None, 56, 56, 384)  1536       ['concatenate_37[0][0]']
#  Normalization)
#
#  activation_137 (Activation)    (None, 56, 56, 384)  0           ['batch_normalization_142[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 56, 56, 128)  49280       ['activation_137[0][0]']
#
#  batch_normalization_143 (Batch  (None, 56, 56, 128)  512        ['conv2d_142[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_143[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_138[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 56, 56, 416)  0           ['concatenate_37[0][0]',
#                                                                   'conv2d_143[0][0]']
#
#  batch_normalization_144 (Batch  (None, 56, 56, 416)  1664       ['concatenate_38[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 56, 56, 416)  0           ['batch_normalization_144[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 56, 56, 128)  53376       ['activation_139[0][0]']
#
#  batch_normalization_145 (Batch  (None, 56, 56, 128)  512        ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_145[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_140[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 56, 56, 448)  0           ['concatenate_38[0][0]',
#                                                                   'conv2d_145[0][0]']
#
#  batch_normalization_146 (Batch  (None, 56, 56, 448)  1792       ['concatenate_39[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 56, 56, 448)  0           ['batch_normalization_146[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 56, 56, 128)  57472       ['activation_141[0][0]']
#
#  batch_normalization_147 (Batch  (None, 56, 56, 128)  512        ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_147[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_142[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 56, 56, 480)  0           ['concatenate_39[0][0]',
#                                                                   'conv2d_147[0][0]']
#
#  batch_normalization_148 (Batch  (None, 56, 56, 480)  1920       ['concatenate_40[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 56, 56, 480)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 56, 56, 128)  61568       ['activation_143[0][0]']
#
#  batch_normalization_149 (Batch  (None, 56, 56, 128)  512        ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 56, 56, 32)   36896       ['activation_144[0][0]']
#
#  concatenate_41 (Concatenate)   (None, 56, 56, 512)  0           ['concatenate_40[0][0]',
#                                                                   'conv2d_149[0][0]']
#
#  batch_normalization_150 (Batch  (None, 56, 56, 512)  2048       ['concatenate_41[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 56, 56, 512)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 56, 56, 256)  131328      ['activation_145[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 28, 28, 256)  0          ['conv2d_150[0][0]']
#  oling2D)
#
#  batch_normalization_151 (Batch  (None, 28, 28, 256)  1024       ['average_pooling2d_4[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 28, 28, 256)  0           ['batch_normalization_151[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 28, 28, 128)  32896       ['activation_146[0][0]']
#
#  batch_normalization_152 (Batch  (None, 28, 28, 128)  512        ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 28, 28, 32)   36896       ['activation_147[0][0]']
#
#  concatenate_42 (Concatenate)   (None, 28, 28, 288)  0           ['average_pooling2d_4[0][0]',
#                                                                   'conv2d_152[0][0]']
#
#  batch_normalization_153 (Batch  (None, 28, 28, 288)  1152       ['concatenate_42[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 28, 28, 288)  0           ['batch_normalization_153[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 28, 28, 128)  36992       ['activation_148[0][0]']
#
#  batch_normalization_154 (Batch  (None, 28, 28, 128)  512        ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_154[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 28, 28, 32)   36896       ['activation_149[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 28, 28, 320)  0           ['concatenate_42[0][0]',
#                                                                   'conv2d_154[0][0]']
#
#  batch_normalization_155 (Batch  (None, 28, 28, 320)  1280       ['concatenate_43[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 28, 28, 320)  0           ['batch_normalization_155[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 28, 28, 128)  41088       ['activation_150[0][0]']
#
#  batch_normalization_156 (Batch  (None, 28, 28, 128)  512        ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_156[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 28, 28, 32)   36896       ['activation_151[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 28, 28, 352)  0           ['concatenate_43[0][0]',
#                                                                   'conv2d_156[0][0]']
#
#  batch_normalization_157 (Batch  (None, 28, 28, 352)  1408       ['concatenate_44[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 28, 28, 352)  0           ['batch_normalization_157[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 28, 28, 128)  45184       ['activation_152[0][0]']
#
#  batch_normalization_158 (Batch  (None, 28, 28, 128)  512        ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_158[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 28, 28, 32)   36896       ['activation_153[0][0]']
#
#  concatenate_45 (Concatenate)   (None, 28, 28, 384)  0           ['concatenate_44[0][0]',
#                                                                   'conv2d_158[0][0]']
#
#  batch_normalization_159 (Batch  (None, 28, 28, 384)  1536       ['concatenate_45[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 28, 28, 384)  0           ['batch_normalization_159[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 28, 28, 128)  49280       ['activation_154[0][0]']
#
#  batch_normalization_160 (Batch  (None, 28, 28, 128)  512        ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_160[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 28, 28, 32)   36896       ['activation_155[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 28, 28, 416)  0           ['concatenate_45[0][0]',
#                                                                   'conv2d_160[0][0]']
#
#  batch_normalization_161 (Batch  (None, 28, 28, 416)  1664       ['concatenate_46[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 28, 28, 416)  0           ['batch_normalization_161[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 28, 28, 128)  53376       ['activation_156[0][0]']
#
#  batch_normalization_162 (Batch  (None, 28, 28, 128)  512        ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_162[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 28, 28, 32)   36896       ['activation_157[0][0]']
#
#  concatenate_47 (Concatenate)   (None, 28, 28, 448)  0           ['concatenate_46[0][0]',
#                                                                   'conv2d_162[0][0]']
#
#  batch_normalization_163 (Batch  (None, 28, 28, 448)  1792       ['concatenate_47[0][0]']
#  Normalization)
#
#  activation_158 (Activation)    (None, 28, 28, 448)  0           ['batch_normalization_163[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 28, 28, 128)  57472       ['activation_158[0][0]']
#
#  batch_normalization_164 (Batch  (None, 28, 28, 128)  512        ['conv2d_163[0][0]']
#  Normalization)
# ...
#  batch_normalization_214 (Batch  (None, 14, 14, 736)  2944       ['concatenate_72[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 14, 14, 736)  0           ['batch_normalization_214[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 14, 14, 128)  94336       ['activation_209[0][0]']
#
#  batch_normalization_215 (Batch  (None, 14, 14, 128)  512        ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_215[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_210[0][0]']
#
#  concatenate_73 (Concatenate)   (None, 14, 14, 768)  0           ['concatenate_72[0][0]',
#                                                                   'conv2d_215[0][0]']
#
#  batch_normalization_216 (Batch  (None, 14, 14, 768)  3072       ['concatenate_73[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 14, 14, 768)  0           ['batch_normalization_216[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 14, 14, 128)  98432       ['activation_211[0][0]']
#
#  batch_normalization_217 (Batch  (None, 14, 14, 128)  512        ['conv2d_216[0][0]']
#  Normalization)
#
#  activation_212 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_217[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_212[0][0]']
#
#  concatenate_74 (Concatenate)   (None, 14, 14, 800)  0           ['concatenate_73[0][0]',
#                                                                   'conv2d_217[0][0]']
#
#  batch_normalization_218 (Batch  (None, 14, 14, 800)  3200       ['concatenate_74[0][0]']
#  Normalization)
#
#  activation_213 (Activation)    (None, 14, 14, 800)  0           ['batch_normalization_218[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 14, 14, 128)  102528      ['activation_213[0][0]']
#
#  batch_normalization_219 (Batch  (None, 14, 14, 128)  512        ['conv2d_218[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_219[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_214[0][0]']
#
#  concatenate_75 (Concatenate)   (None, 14, 14, 832)  0           ['concatenate_74[0][0]',
#                                                                   'conv2d_219[0][0]']
#
#  batch_normalization_220 (Batch  (None, 14, 14, 832)  3328       ['concatenate_75[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 14, 14, 832)  0           ['batch_normalization_220[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 14, 14, 128)  106624      ['activation_215[0][0]']
#
#  batch_normalization_221 (Batch  (None, 14, 14, 128)  512        ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_221[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_216[0][0]']
#
#  concatenate_76 (Concatenate)   (None, 14, 14, 864)  0           ['concatenate_75[0][0]',
#                                                                   'conv2d_221[0][0]']
#
#  batch_normalization_222 (Batch  (None, 14, 14, 864)  3456       ['concatenate_76[0][0]']
#  Normalization)
#
#  activation_217 (Activation)    (None, 14, 14, 864)  0           ['batch_normalization_222[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 14, 14, 128)  110720      ['activation_217[0][0]']
#
#  batch_normalization_223 (Batch  (None, 14, 14, 128)  512        ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_223[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_218[0][0]']
#
#  concatenate_77 (Concatenate)   (None, 14, 14, 896)  0           ['concatenate_76[0][0]',
#                                                                   'conv2d_223[0][0]']
#
#  batch_normalization_224 (Batch  (None, 14, 14, 896)  3584       ['concatenate_77[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 14, 14, 896)  0           ['batch_normalization_224[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 14, 14, 128)  114816      ['activation_219[0][0]']
#
#  batch_normalization_225 (Batch  (None, 14, 14, 128)  512        ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_225[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_220[0][0]']
#
#  concatenate_78 (Concatenate)   (None, 14, 14, 928)  0           ['concatenate_77[0][0]',
#                                                                   'conv2d_225[0][0]']
#
#  batch_normalization_226 (Batch  (None, 14, 14, 928)  3712       ['concatenate_78[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 14, 14, 928)  0           ['batch_normalization_226[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 14, 14, 128)  118912      ['activation_221[0][0]']
#
#  batch_normalization_227 (Batch  (None, 14, 14, 128)  512        ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_227[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_222[0][0]']
#
#  concatenate_79 (Concatenate)   (None, 14, 14, 960)  0           ['concatenate_78[0][0]',
#                                                                   'conv2d_227[0][0]']
#
#  batch_normalization_228 (Batch  (None, 14, 14, 960)  3840       ['concatenate_79[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 14, 14, 960)  0           ['batch_normalization_228[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 14, 14, 128)  123008      ['activation_223[0][0]']
#
#  batch_normalization_229 (Batch  (None, 14, 14, 128)  512        ['conv2d_228[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_229[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_224[0][0]']
#
#  concatenate_80 (Concatenate)   (None, 14, 14, 992)  0           ['concatenate_79[0][0]',
#                                                                   'conv2d_229[0][0]']
#
#  batch_normalization_230 (Batch  (None, 14, 14, 992)  3968       ['concatenate_80[0][0]']
#  Normalization)
#
#  activation_225 (Activation)    (None, 14, 14, 992)  0           ['batch_normalization_230[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 14, 14, 128)  127104      ['activation_225[0][0]']
#
#  batch_normalization_231 (Batch  (None, 14, 14, 128)  512        ['conv2d_230[0][0]']
#  Normalization)
#
#  activation_226 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_231[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 14, 14, 32)   36896       ['activation_226[0][0]']
#
#  concatenate_81 (Concatenate)   (None, 14, 14, 1024  0           ['concatenate_80[0][0]',
#                                 )                                 'conv2d_231[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 2, 2, 1024)  0           ['concatenate_81[0][0]']
#  oling2D)
#
#  dense_1 (Dense)                (None, 2, 2, 1000)   1025000     ['average_pooling2d_6[0][0]']
#
# ==================================================================================================
# Total params: 8,068,404
# Trainable params: 7,986,926
# Non-trainable params: 81,478
# __________________________________________________________________________________________________
