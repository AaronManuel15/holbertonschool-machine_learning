# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
"""Task 0. Flip"""


def flip_image(image):
    """Function that flips an image horizontally"""
    return tf.image.flip_left_right(image)

# %%
tf.compat.v1.enable_eager_execution()
tf.compat.v1.set_random_seed(0)

doggies = tfds.load('stanford_dogs', split='train', as_supervised=True)
for image, _ in doggies.shuffle(10).take(1):
    plt.imshow(flip_image(image))
    plt.show()

# %%
"""Task 1. Crop"""


def crop_image(image, size):
    """Performs a random crop of an image
    Args:
        image: a tensor of shape (height, width, channels)
        size: a tuple (new_height, new_width)
    Returns:
        a tensor of shape (new_height, new_width, channels)
    """
    return tf.image.random_crop(image, size)

# %%
tf.compat.v1.set_random_seed(1)

doggies = tfds.load('stanford_dogs', split='train', as_supervised=True)
for image, _ in doggies.shuffle(10).take(1):
    plt.imshow(crop_image(image, (200, 200, 3)))
    plt.show()

# %%
"""Task 2. Rotate"""


def rotate_image(image):
    """Rotates an image 90 degrees clockwise
    Args:
        image: a tensor of shape (height, width, channels)
    Returns:
        a tensor of shape (width, height, channels)
    """
    return tf.image.rot90(image)

# %%
tf.compat.v1.set_random_seed(2)

doggies = tfds.load('stanford_dogs', split='train', as_supervised=True)
for image, _ in doggies.shuffle(10).take(1):
    plt.imshow(rotate_image(image))
    plt.show()

# %%
"""Task 3. Shear"""


def shear_image(image, intensity):
    """Randomly shears an image
    Args:
        image: a tensor of shape (height, width, channels)
        intensity: a number
    Returns:
        a tensor of shape (height, width, channels)
    """
    return tf.keras.preprocessing.image.random_shear(image,
                                                     intensity,
                                                     row_axis=1,
                                                     col_axis=0,
                                                     channel_axis=2)

# %%
tf.compat.v1.set_random_seed(3)

doggies = tfds.load('stanford_dogs', split='train', as_supervised=True)
for image, _ in doggies.shuffle(10).take(1):
    plt.imshow(shear_image(image, 50))
    plt.show()

# %%
"""Task 4. Brightness"""


def change_brightness(image, max_delta):
    """Randomly changes the brightness of an image
    Args:
        image: a tensor of shape (height, width, channels)
        max_delta: the maximum amount to change the brightness by
    Returns:
        a tensor of shape (height, width, channels)
    """
    return tf.image.random_brightness(image, max_delta)

# %%
tf.compat.v1.set_random_seed(4)

doggies = tfds.load('stanford_dogs', split='train', as_supervised=True)
for image, _ in doggies.shuffle(10).take(1):
    plt.imshow(change_brightness(image, 0.3))
    plt.show()

# %%
"""Task 5. Hue"""


def change_hue(image, delta):
    """Changes the hue of an image
    Args:
        image: a tensor of shape (height, width, channels)
        delta: amount the hue should be changed by
    Returns:
        a tensor of shape (height, width, channels)
    """
    return tf.image.adjust_hue(image, delta)

# %%
tf.compat.v1.set_random_seed(5)

doggies = tfds.load('stanford_dogs', split='train', as_supervised=True)
for image, _ in doggies.shuffle(10).take(1):
    plt.imshow(change_hue(image, -0.5))
    plt.show()
